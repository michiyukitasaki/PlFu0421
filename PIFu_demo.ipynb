# %% [markdown]
# <a href="https://colab.research.google.com/github/cedro3/PIFu/blob/master/PIFu_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Githubからコードをコピー

# %%
# !git clone https://github.com/cedro3/PIFu.git

# %%
cd /content/PIFu

# %% [markdown]
# # 学習済みモデルのダウンロード

# %%
# !sh ./scripts/download_trained_model.sh

# %% [markdown]
# # PIFu デモ1 (sample_images/mana)

# %%
# 使用するデータを選択します
# !sh ./scripts/test.sh './sample_images/mana' 'mana'

# %%
# レンダリング(10数分程度掛かります)
# !pip install 'git+https://github.com/facebookresearch/pytorch3d.git@stable'

# %%
# mp4を作成します
from lib.colab_util import *
obj_path = '/content/PIFu/results/mana/result_mana.obj'
video_path = '/content/PIFu/results/mana/result_mana.mp4'
video_display_path = '/content/PIFu/results/mana/result_mana_display.mp4'

renderer = set_renderer()
generate_video_from_obj(obj_path, video_path, renderer)

# we cannot play a mp4 video generated by cv2
# !ffmpeg -i $video_path -vcodec libx264 $video_display_path -y -loglevel quiet
video(video_display_path)

# %% [markdown]
# # PIFu デモ2 (sample_images/yui)

# %%
# 使用するデータを選択します
# !sh ./scripts/test.sh './sample_images/yui' 'yui'

# %%
# レンダリング(10数分程度掛かります)
# !pip install 'git+https://github.com/facebookresearch/pytorch3d.git@stable'

# %%
# mp4を作成します
from lib.colab_util import *
obj_path = '/content/PIFu/results/yui/result_yui.obj'
video_path = '/content/PIFu/results/yui/result_yui.mp4'
video_display_path = '/content/PIFu/results/yui/result_yui_display.mp4'

renderer = set_renderer()
generate_video_from_obj(obj_path, video_path, renderer)

# we cannot play a mp4 video generated by cv2
# !ffmpeg -i $video_path -vcodec libx264 $video_display_path -y -loglevel quiet
video(video_display_path)

# %% [markdown]
# # PIFu デモ3 (sample_images/yuriko)

# %%
# 使用するデータを選択します
# !sh ./scripts/test.sh './sample_images/yuriko' 'yuriko'

# %%
# レンダリング(10数分程度掛かります)
# !pip install 'git+https://github.com/facebookresearch/pytorch3d.git@stable'

# %%
# mp4を作成します
from lib.colab_util import *
obj_path = '/content/PIFu/results/yuriko/result_yuriko.obj'
video_path = '/content/PIFu/results/yuriko/result_yuriko.mp4'
video_display_path = '/content/PIFu/results/yuriko/result_yuriko_display.mp4'

renderer = set_renderer()
generate_video_from_obj(obj_path, video_path, renderer)

# we cannot play a mp4 video generated by cv2
# !ffmpeg -i $video_path -vcodec libx264 $video_display_path -y -loglevel quiet
video(video_display_path)

# %% [markdown]
# # PIFu デモ4 (sample_images/kako)

# %%
# 使用するデータを選択します
# !sh ./scripts/test.sh './sample_images/kako' 'kako'

# %%
# レンダリング(10数分程度掛かります)
# !pip install 'git+https://github.com/facebookresearch/pytorch3d.git@stable'

# %%
# mp4を作成します
from lib.colab_util import *
obj_path = '/content/PIFu/results/kako/resul_kako.obj'
video_path = '/content/PIFu/results/kako/result_kako.mp4'
video_display_path = '/content/PIFu/results/kako/result_kako_display.mp4'

renderer = set_renderer()
generate_video_from_obj(obj_path, video_path, renderer)

# we cannot play a mp4 video generated by cv2
# !ffmpeg -i $video_path -vcodec libx264 $video_display_path -y -loglevel quiet
video(video_display_path)
